# %%
from selenium import webdriver as wd
import urllib

# %%
target_url = 'http://www.opinet.co.kr/searRgSelect.do'

# %%
driver = wd.Chrome('../tool/chromedriver.exe')

# %%
# 해당 사이트가 중간 페이지를 직접 접속하는 부분을 거부하기 때문에
import time
for n in range(2) :
    driver.get(target_url)
    time.sleep(5)

# %% [markdown]
# 1. 시도 정보를 추출하여 리스트화
# 2. 리스트를 반복하면서 해당 시도 밑에 시군구 리스트화
# 3. 시군구 리스트를 반복하면서 읍면동 리스트화
# 4. 읍면동 리스트 반복하면서 조회 -> 다운로드
# 5. 사이트 관찰 결과, 시도, 시군구, 읍면동 정보가 새로 세팅되면 화면의 DOM이 모두 새로 구성되는 문제가 있어서 반복문 안에서는 반드시 시도, 시군구, 읍면동을 새로 잡아줘야 한다!(매우 중요)
# 6. (여기서는) 시군구를 반복하면서 바로 조회 및 다운로드로 전개하겠다

# %%
# 시도 리스트 획득
sido = driver.find_element_by_id('SIDO_NM0')
sidos = [option.get_attribute('value')
         for option in driver.find_elements_by_css_selector('#SIDO_NM0 > option')
         if option.get_attribute('value')]
# 데이터의 상위값, 하위값 조사를 통해 샘플링으로 확인
sidos[:2], sidos[-2:]
# Out:
# (['서울특별시', '부산광역시'], ['경상남도', '제주특별자치도'])

# %%
# 2. 시도 리스트를 반복하면서 해당 시도 밑에 시군구 리스트화
# sidos 중에 '부산광역시' 대상으로 수집하겠다
for sido_name in sidos[1:2] :
    # 2-1. sido 대상 찾아서
    sido = driver.find_element_by_id('SIDO_NM0')
    # 2-2. sido 값을 설정
    sido.send_keys(sido_name)
    # 2-2-2. 잠시대기(ajax 통신 후 화면이 재구성될 때까지)
    time.sleep(4)
    # 2-3. 시군구 리스트 획득
    sigungus = [option.get_attribute('value')
         for option in driver.find_elements_by_css_selector('#SIGUNGU_NM0 > option')
         if option.get_attribute('value')]
    print(sido_name, sigungus[:2])
    # 2-4. 반복~ 3단계로 진입
    # 3. 시군구 리스트를 반복하면서 -> 잠시대기(5초대기) -> 엑셀저장
    for sigungu_name in sigungus :
        # 3-1. 시군구 태그를 찾아서
        sigungu = driver.find_element_by_id('SIGUNGU_NM0')
        # 3-2. 시군구값 설정
        sigungu.send_keys(sigungu_name)
        # 3-3. 잠시 대기
        time.sleep(5)
        # 3-4. 엑셀 저장
        driver.find_element_by_id('glopopd_excel').click()
# Out:
# 부산광역시 ['강서구', '금정구']

# %% [markdown]
# ### 데이터 수집 완료
#
# - 수십 개의 엑셀 파일을 반복적으로 읽어서 DataFrame으로 구성하기

# %%
# glob 특정 위치상에 존재하는 파일들을 패턴을 지정하여 목록을 구할 수 있다
from glob import glob
import pandas as pd

# %%
# 부산 관할 시군구에 조회된 엑셀 자료를 읽을 수 있게 파일 경로를 리스트화
down_files = glob('C:/Users/User/Downloads/지역*.xls')
down_files
# Out:
# ['C:/Users/User/Downloads\\지역_위치별(주유소) (1).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (10).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (11).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (12).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (13).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (14).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (15).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (2).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (3).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (4).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (5).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (6).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (7).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (8).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소) (9).xls',
#  'C:/Users/User/Downloads\\지역_위치별(주유소).xls']

# %%
# conda install xlrd

# %%
tmp_raws = []
for file in down_files :
    tmp = pd.read_excel(file, header = 2)
    tmp_raws.append(tmp)
# 데이터 확인
st_raw = pd.concat(tmp_raws)

# %%
st_raw
# Out:
#        지역                   상호                           주소      상표  \
# 0   부산광역시              청룡명품주유소             부산 금정구  중앙대로2130  현대오일뱅크
# 1   부산광역시             훼미리알뜰주유소           부산 금정구 두실로 2 (남산동)   알뜰주유소
# 2   부산광역시       에스원에너지(주)금강주유소             부산 금정구 중앙대로 1972   SK에너지
# 3   부산광역시           은마석유 노포주유소       부산 금정구 중앙대로 2191 (노포동)   GS칼텍스
# 4   부산광역시     광신석유(주)직영경부고속주유소    부산 금정구 중앙대로1720번길 7 (부곡동)   SK에너지
# 5   부산광역시       지에스칼텍스(주)신창주유소      부산 금정구  중앙대로 1698 (부곡동)   GS칼텍스
# 6   부산광역시               A1 주유소          부산 금정구 반송로 364 (서동)  현대오일뱅크
# 7   부산광역시   현대오일뱅크㈜ 직영 금정셀프주유소       부산 금정구 중앙대로 1664 (부곡동)  현대오일뱅크
# 8   부산광역시           거북이주유소(SK)       부산 금정구 중앙대로 1672 (부곡동)   SK에너지
# 9   부산광역시    현대오일뱅크㈜직영 부곡셀프주유소       부산 금정구 중앙대로 1597 (부곡동)  현대오일뱅크
# 10  부산광역시     한솔유화(주) 직영 한길주유소       부산 금정구 중앙대로 1646 (부곡동)  현대오일뱅크
# 11  부산광역시                동진주유소       부산 금정구 금정로 216,  (구서동)   SK에너지
# 12  부산광역시               금샘로주유소         부산 금정구 금샘로 460 (남산동)   SK에너지
# 13  부산광역시                신화주유소               부산 금정구 금강로 721  현대오일뱅크
# 14  부산광역시              금두꺼비주유소      부산광역시 금정구  부곡로 67 (부곡동)  현대오일뱅크
# 15  부산광역시                지현주유소     부산광역시 금정구 중앙대로 2044(남산동)   S-OIL
# 16  부산광역시                동양주유소         부산 금정구  반송로 391 (서동)  현대오일뱅크
# 17  부산광역시               금정산주유소         부산 금정구 금샘로 399 (구서동)   SK에너지
# 18  부산광역시               식물원주유소          부산 금정구 금샘로 21 (장전동)   S-OIL
# 19  부산광역시                금사주유소         부산 금정구 반송로 420 (금사동)   SK에너지
# 20  부산광역시       지에스칼텍스(주)영풍주유소       부산 금정구 중앙대로 1782 (부곡동)   GS칼텍스
# 21  부산광역시                석2주유소         부산 금정구 식물원로 21 (장전동)   GS칼텍스
# 22  부산광역시               새석대주유소         부산 금정구 반송로 463 (금사동)   S-OIL
# 23  부산광역시                   국제             부산 금정구 중앙대로 1756   SK에너지
# 0   부산광역시             (주)디시에너지               부산 서구 보수대로 220  현대오일뱅크
# 1   부산광역시              스타2 주유소        부산광역시 서구 원양로 260(암남동)   GS칼텍스
# 2   부산광역시      동방석유(주)직영 모든주유소      부산광역시 서구  감천로 227 (암남동)   SK에너지
# 3   부산광역시        (주)디시에너지 대신지점                 부산 서구 대영로 91  현대오일뱅크
# 4   부산광역시      CJ대한통운㈜ 우양냉장주유소        부산 서구 충무대로 240 (남부민동)   S-OIL
# 5   부산광역시            남항대교셀프주유소         부산 서구 충무대로 108 (암남동)    자가상표
# ..    ...                  ...                          ...     ...
# 19  부산광역시                오봉주유소           부산 강서구 호계로 1 (죽림동)   SK에너지
# 20  부산광역시  (주)우양네트웍스 구도일주유소 삼광        부산 강서구 공항로 799 (대저2동)   S-OIL
# 21  부산광역시                금룡주유소       부산 강서구 가락대로 1361 (봉림동)   S-OIL
# 22  부산광역시            (주)신항만에너지    부산광역시 강서구  낙동남로 507 (녹산동)   S-OIL
# 23  부산광역시              김해공항주유소   부산광역시 강서구  공항진입로 25 (대저2동)   GS칼텍스
# 24  부산광역시                유성주유소         부산 강서구 생곡로 337 (생곡동)   S-OIL
# 25  부산광역시                제일주유소          부산광역시 강서구 가락대로 1417   GS칼텍스
# 26  부산광역시             (주)우보주유소        부산 강서구 낙동북로 142 (강동동)   S-OIL
# 27  부산광역시           녹산화물터미널주유소      부산 강서구 녹산산업북로 119 (송정동)   GS칼텍스
# 28  부산광역시       대양산업(주)대양가덕주유소     부산 강서구 거가대로 2571,  (천성동)   GS칼텍스
# 29  부산광역시                현대주유소       부산 강서구 낙동북로 209 (대저1동)   S-OIL
# 30  부산광역시             (주)범방주유소    부산광역시 강서구  가락대로 963 (범방동)   SK에너지
# 31  부산광역시        CJ대한통운㈜ 성민주유소        부산 강서구 가락대로 389 (송정동)   S-OIL
# 32  부산광역시                맥도주유소        부산 강서구 공항로 381 (대저2동)   SK에너지
# 33  부산광역시                성산주유소         부산 강서구 생곡로 140 (녹산동)   S-OIL
# 34  부산광역시                명품주유소        부산 강서구 대저로 283 (대저1동)  현대오일뱅크
# 35  부산광역시              영남셀프주유소        부산 강서구 공항로 115 (대저2동)   GS칼텍스
# 36  부산광역시        인터지스(주) 신항주유소              부산 강서구 가락대로 649  현대오일뱅크
# 37  부산광역시                녹산주유소              부산 강서구 낙동남로 700   S-OIL
# 38  부산광역시     내트럭(주) 부산신항남컨사업소              부산 강서구 신항남로 507   SK에너지
# 39  부산광역시           (주)비에스이주유소     부산광역시 강서구  낙동북로 18 (강동동)  현대오일뱅크
# 40  부산광역시              대저고속주유소       부산 강서구 체육공원로 66 (대저1동)   GS칼텍스
# 41  부산광역시        대양석유(주)한마음주유소        부산 강서구 르노삼성로 77 (명지동)   SK에너지
# 42  부산광역시              명지대교주유소  부산광역시 강서구  르노삼성대로 572 (명지동)   GS칼텍스
# 43  부산광역시        CJ대한통운㈜ 고려주유소      부산 강서구 르노삼성대로 586 (명지동)   S-OIL
# 44  부산광역시     광신석유(주)직영부산신항주유소      부산 강서구 르노삼성대로 372 (명지동)   SK에너지
# 45  부산광역시                명지주유소             부산 강서구 낙동남로 1042   SK에너지
# 46  부산광역시                만선주유소         부산 강서구 가락대로210번길 102  현대오일뱅크
# 47  부산광역시              동성셀프주유소   부산광역시 강서구 명지국제8로 272 (명지동)   S-OIL
# 48  부산광역시       SK에너지(주)새부산주유소         부산 강서구 낙동북로 42 (강동동)   SK에너지
#
#              전화번호 셀프여부 고급휘발유   휘발유    경유  실내등유
# 0